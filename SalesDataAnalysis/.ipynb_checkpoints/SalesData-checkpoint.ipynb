# %% [markdown]
# ## import required libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### import dataset

# %%
data=pd.read_csv("Sales-Data-Analysis.csv")

# %%
data.head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin

# %%
data.info
# Out:
# <bound method DataFrame.info of      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0       10452  07-11-2022               Fries   3.49    573.07       Online
# 1       10453  07-11-2022           Beverages   2.95    745.76       Online
# 2       10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3       10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4       10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# ..        ...         ...                 ...    ...       ...           ...
# 249     10709  28-12-2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  29-12-2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  29-12-2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  29-12-2022               Fries   3.49    630.37   Drive-thru
# 253     10713  29-12-2022           Beverages   2.95    677.97   Drive-thru
#
# ...

# %% [markdown]
# ## consider the manager columns

# %%
data.Manager
# Out:
# 0        Tom      Jackson
# 1             Pablo Perez
# 2           Joao    Silva
# 3           Walter Muller
# 4           Walter Muller
#               ...
# 249         Walter Muller
# 250         Walter Muller
# 251         Walter Muller
# 252         Walter Muller
# 253         Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
data.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
data.Manager.nunique()
# Out:
# 14

# %%
data['Manager'].str.strip().str.replace(r'\s+',' ',regex=True)
# Out:
# 0        Tom Jackson
# 1        Pablo Perez
# 2         Joao Silva
# 3      Walter Muller
# 4      Walter Muller
#            ...
# 249    Walter Muller
# 250    Walter Muller
# 251    Walter Muller
# 252    Walter Muller
# 253    Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
data.Manager=data['Manager'].str.strip().str.replace(r'\s+',' ',regex=True)

# %%
data.Manager.nunique()
# Out:
# 5

# %%
data.Manager.unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %% [markdown]
# ## Removing duplicates records

# %%
data.describe()
# Out:
#            Order ID       Price    Quantity
# count    254.000000  254.000000  254.000000
# mean   10584.133858    7.102323  460.611457
# std       75.889181    4.341855  214.888699
# min    10452.000000    2.950000  200.400000
# 25%    10520.250000    3.490000  201.010000
# 50%    10583.500000    4.990000  538.880000
# 75%    10649.750000    9.950000  677.440000
# max    10713.000000   29.050000  754.430000

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
## Therefore there is no duplicates

# %%
data[data['Order ID'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %% [markdown]
# ## converting datatypes of the coluns

# %%
data.dtypes
# Out:
# Order ID            int64
# Date               object
# Product            object
# Price             float64
# Quantity          float64
# Purchase Type      object
# Payment Method     object
# Manager            object
# City               object
# dtype: object

# %%
# data.columnName=data.columnName.astype(type eg float)

# %%
data.Quantity
# Out:
# 0      573.07
# 1      745.76
# 2      200.40
# 3      569.67
# 4      201.01
#         ...
# 249    200.40
# 250    754.43
# 251    281.41
# 252    630.37
# 253    677.97
# Name: Quantity, Length: 254, dtype: float64

# %%
data.Quantity=data.Quantity.round()

# %%
data.Quantity=data.Quantity.astype(int)

# %%
data.Quantity
# Out:
# 0      573
# 1      746
# 2      200
# 3      570
# 4      201
#       ...
# 249    200
# 250    754
# 251    281
# 252    630
# 253    678
# Name: Quantity, Length: 254, dtype: int64

# %%
data.dtypes
# Out:
# Order ID            int64
# Date               object
# Product            object
# Price             float64
# Quantity            int64
# Purchase Type      object
# Payment Method     object
# Manager            object
# City               object
# dtype: object

# %%
data.Date=pd.to_datetime(data.Date,format='mixed')

# %%
data.dtypes
# Out:
# Order ID                   int64
# Date              datetime64[ns]
# Product                   object
# Price                    float64
# Quantity                   int64
# Purchase Type             object
# Payment Method            object
# Manager                   object
# City                      object
# dtype: object

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-07-11               Fries   3.49       573       Online
# 1     10453 2022-07-11           Beverages   2.95       746       Online
# 2     10454 2022-07-11       Sides & Other   4.99       200     In-store
# 3     10455 2022-08-11             Burgers  12.99       570     In-store
# 4     10456 2022-08-11  Chicken Sandwiches   9.95       201     In-store
#
#   Payment Method        Manager    City
# 0      Gift Card    Tom Jackson  London
# 1      Gift Card    Pablo Perez  Madrid
# 2      Gift Card     Joao Silva  Lisbon
# 3    Credit Card  Walter Muller  Berlin
# 4    Credit Card  Walter Muller  Berlin

# %% [markdown]
# ## Analyze Data

# %% [markdown]
# ### Q1.What is the most preffered payment method

# %%
data.head(2)
# Out:
#    Order ID       Date    Product  Price  Quantity Purchase Type  \
# 0     10452 2022-07-11      Fries   3.49       573       Online
# 1     10453 2022-07-11  Beverages   2.95       746       Online
#
#   Payment Method      Manager    City
# 0      Gift Card  Tom Jackson  London
# 1      Gift Card  Pablo Perez  Madrid

# %%
data['Payment Method'].unique()
# Out:
# array([' Gift Card', ' Credit Card', ' Cash'], dtype=object)

# %%
data.groupby('Payment Method')['Payment Method'].value_counts()
# Out:
# Payment Method
# Cash            76
# Credit Card    120
# Gift Card       58
# Name: count, dtype: int64

# %%
data.groupby('Payment Method')['Payment Method'].value_counts()

# %%
data['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    120
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %%
#check in percentage
data['Payment Method'].value_counts(normalize=True)*100
# Out:
# Payment Method
# Credit Card    47.244094
# Cash           29.921260
# Gift Card      22.834646
# Name: proportion, dtype: float64

# %%
data['Payment Method'].value_counts().plot(kind='bar');

# %% [markdown]
# ## Q.2 Most selling Product

# %% [markdown]
# - By Quantity
# - By Revenue

# %%
data.head(2)
# Out:
#    Order ID       Date    Product  Price  Quantity Purchase Type  \
# 0     10452 2022-07-11      Fries   3.49       573       Online
# 1     10453 2022-07-11  Beverages   2.95       746       Online
#
#   Payment Method      Manager    City
# 0      Gift Card  Tom Jackson  London
# 1      Gift Card  Pablo Perez  Madrid

# %%
data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product
# Beverages             34988
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
most_quantity=data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
most_quantity
# Out:
# Product
# Beverages             34988
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
type(most_quantity)
# Out:
# pandas.core.series.Series

# %%
most_quantity=most_quantity.reset_index()

# %%
most_quantity
# Out:
#               Product  Quantity
# 0           Beverages     34988
# 1               Fries     32023
# 2             Burgers     29018
# 3  Chicken Sandwiches     11133
# 4       Sides & Other      9800

# %%
plt.figure(figsize=(9,4))
plt.bar(most_quantity.Product,most_quantity.Quantity,color=['red','black', 'green','yellow','cyan'],width=.4);
plt.title('Most selling product')
plt.xlabel('Product')
plt.ylabel('Quantity')
# Out:
# Text(0, 0.5, 'Quantity')

# %%
data['Revenue']=data.Price*data.Quantity

# %%
data.head(3)
# Out:
#    Order ID       Date        Product  Price  Quantity Purchase Type  \
# 0     10452 2022-07-11          Fries   3.49       573       Online
# 1     10453 2022-07-11      Beverages   2.95       746       Online
# 2     10454 2022-07-11  Sides & Other   4.99       200     In-store
#
#   Payment Method      Manager    City  Revenue
# 0      Gift Card  Tom Jackson  London  1999.77
# 1      Gift Card  Pablo Perez  Madrid  2200.70
# 2      Gift Card   Joao Silva  Lisbon   998.00

# %%
data.groupby('Product')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Product
# Burgers               376943.82
# Fries                 125626.57
# Chicken Sandwiches    114612.45
# Beverages             103214.60
# Sides & Other          48902.00
# Name: Revenue, dtype: float64

# %%
most_revenue=data.groupby('Product')['Revenue'].sum().sort_values(ascending=False)
most_revenue
# Out:
# Product
# Burgers               376943.82
# Fries                 125626.57
# Chicken Sandwiches    114612.45
# Beverages             103214.60
# Sides & Other          48902.00
# Name: Revenue, dtype: float64

# %%
type(most_revenue)
# Out:
# pandas.core.series.Series

# %%
most_revenue=most_revenue.reset_index()

# %%
most_revenue
# Out:
#               Product    Revenue
# 0             Burgers  376943.82
# 1               Fries  125626.57
# 2  Chicken Sandwiches  114612.45
# 3           Beverages  103214.60
# 4       Sides & Other   48902.00

# %%
plt.bar(most_revenue.Product,most_revenue.Revenue);
plt.title('Most selling product')
plt.xlabel('Product')
plt.ylabel('Revenue')
# Out:
# Text(0, 0.5, 'Revenue')

# %% [markdown]
# ### Q.3 Which city had maxumum revenue
# ### or
# ### Which manager earned maximum revenue

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-07-11               Fries   3.49       573       Online
# 1     10453 2022-07-11           Beverages   2.95       746       Online
# 2     10454 2022-07-11       Sides & Other   4.99       200     In-store
# 3     10455 2022-08-11             Burgers  12.99       570     In-store
# 4     10456 2022-08-11  Chicken Sandwiches   9.95       201     In-store
#
#   Payment Method        Manager    City  Revenue
# 0      Gift Card    Tom Jackson  London  1999.77
# 1      Gift Card    Pablo Perez  Madrid  2200.70
# 2      Gift Card     Joao Silva  Lisbon   998.00
# 3    Credit Card  Walter Muller  Berlin  7404.30
# 4    Credit Card  Walter Muller  Berlin  1999.95

# %%
data.City.unique()
# Out:
# array(['London', 'Madrid', 'Lisbon', 'Berlin', 'Paris'], dtype=object)

# %%
data.groupby('City')['Revenue'].sum().sort_values(ascending=False)
# Out:
# City
# Lisbon    241635.49
# London    211160.04
# Madrid    136154.24
# Berlin    100572.34
# Paris      79777.33
# Name: Revenue, dtype: float64

# %%
data.head(2)
# Out:
#    Order ID       Date    Product  Price  Quantity Purchase Type  \
# 0     10452 2022-07-11      Fries   3.49       573       Online
# 1     10453 2022-07-11  Beverages   2.95       746       Online
#
#   Payment Method      Manager    City  Revenue
# 0      Gift Card  Tom Jackson  London  1999.77
# 1      Gift Card  Pablo Perez  Madrid  2200.70

# %%
data.Manager.unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
data.groupby('Manager')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Manager
# Joao Silva       241635.49
# Tom Jackson      211160.04
# Pablo Perez      136154.24
# Walter Muller    100572.34
# Remy Monet        79777.33
# Name: Revenue, dtype: float64

# %% [markdown]
# ### Q.4 Date wise Revenue

# %%
data.head(2)
# Out:
#    Order ID       Date    Product  Price  Quantity Purchase Type  \
# 0     10452 2022-07-11      Fries   3.49       573       Online
# 1     10453 2022-07-11  Beverages   2.95       746       Online
#
#   Payment Method      Manager    City  Revenue
# 0      Gift Card  Tom Jackson  London  1999.77
# 1      Gift Card  Pablo Perez  Madrid  2200.70

# %%
data.plot('Date','Revenue', color='red',linewidth=2,figsize=(9,4))
# set title etc
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Q5.What is the average revenue

# %%
data.Revenue.mean()
# Out:
# np.float64(3028.737952755905)

# %% [markdown]
# ### Q6.What is the average Revenue of November & December month

# %%
data.head(3)
# Out:
#    Order ID       Date        Product  Price  Quantity Purchase Type  \
# 0     10452 2022-07-11          Fries   3.49       573       Online
# 1     10453 2022-07-11      Beverages   2.95       746       Online
# 2     10454 2022-07-11  Sides & Other   4.99       200     In-store
#
#   Payment Method      Manager    City  Revenue
# 0      Gift Card  Tom Jackson  London  1999.77
# 1      Gift Card  Pablo Perez  Madrid  2200.70
# 2      Gift Card   Joao Silva  Lisbon   998.00

# %%
data['Month']=data.Date.dt.month

# %%
data.head(2)
# Out:
#    Order ID       Date    Product  Price  Quantity Purchase Type  \
# 0     10452 2022-07-11      Fries   3.49       573       Online
# 1     10453 2022-07-11  Beverages   2.95       746       Online
#
#   Payment Method      Manager    City  Revenue  Month
# 0      Gift Card  Tom Jackson  London  1999.77      7
# 1      Gift Card  Pablo Perez  Madrid  2200.70      7

# %%
m11=data[data.Month==11]
m11
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 16      10470 2022-11-11             Burgers  12.99       554     In-store
# 17      10471 2022-11-11  Chicken Sandwiches   9.95       201     In-store
# 18      10472 2022-11-11               Fries   3.49       630     In-store
# 19      10473 2022-11-11           Beverages   2.95       678     In-store
# 20      10474 2022-11-11       Sides & Other   4.99       200     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 160     10620 2022-11-12             Burgers  12.99       585       Online
# 161     10621 2022-11-12  Chicken Sandwiches   9.95       201       Online
# 162     10622 2022-11-12               Fries   3.49       630       Online
# 163     10623 2022-11-12           Beverages   2.95       746       Online
# 164     10624 2022-11-12       Sides & Other   4.99       200       Online
#
#     Payment Method      Manager    City  Revenue  Month
# ...

# %%
m11.Revenue.mean()
# Out:
# np.float64(2969.3819587628864)

# %%
m12=data[data.Month==12]
m12
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 21      10475 2022-12-11             Burgers  12.99       523     In-store
# 22      10476 2022-12-11  Chicken Sandwiches   9.95       201     In-store
# 23      10477 2022-12-11               Fries   3.49       630     In-store
# 24      10478 2022-12-11           Beverages   2.95       678     In-store
# 25      10479 2022-12-11       Sides & Other   4.99       200     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 249     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 250     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 252     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 253     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
#     Payment Method        Manager    City  Revenue  Month
# ...

# %%
m12.Revenue.mean()
# Out:
# np.float64(3194.7782978723403)

# %% [markdown]
# ### Q7. Standardd Deviation of Revenue and Quantity

# %%
data.Quantity.std()
# Out:
# 214.97943096363838

# %%
data.Revenue.std()
# Out:
# 2419.9325462715055

# %% [markdown]
# ### Q8.What is the variance of Revenue and Quantity

# %%
data.Revenue.var()
# Out:
# 5856073.528504092

# %%
data.Quantity.var()
# Out:
# 46216.155737449764

# %% [markdown]
# ### Q9.Is Revenue increasing or decreasing over time

# %%
data.groupby('Month')['Revenue'].sum()
# Out:
# Month
# 1      13401.89
# 2      13990.52
# 3      13990.52
# 4       9001.56
# 5      14194.28
# 6      13999.43
# 7      19188.99
# 8      26600.38
# 9      28795.33
# 10     27797.33
# 11    288030.05
# 12    300309.16
# Name: Revenue, dtype: float64

# %%
#its increasing over time

# %% [markdown]
# ## Q10.Average Quantity sold & Average Revenue for each product

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-07-11               Fries   3.49       573       Online
# 1     10453 2022-07-11           Beverages   2.95       746       Online
# 2     10454 2022-07-11       Sides & Other   4.99       200     In-store
# 3     10455 2022-08-11             Burgers  12.99       570     In-store
# 4     10456 2022-08-11  Chicken Sandwiches   9.95       201     In-store
#
#   Payment Method        Manager    City  Revenue  Month
# 0      Gift Card    Tom Jackson  London  1999.77      7
# 1      Gift Card    Pablo Perez  Madrid  2200.70      7
# 2      Gift Card     Joao Silva  Lisbon   998.00      7
# 3    Credit Card  Walter Muller  Berlin  7404.30      8
# 4    Credit Card  Walter Muller  Berlin  1999.95      8

# %%
data.groupby('Product')['Quantity','Revenue'].agg({'Quantity':'mean','Revenue':'mean'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 data.groupby('Product')['Quantity','Revenue'].agg({'Quantity':'mean','Revenue':'mean'})
#
# File ~\.conda\envs\ds_env\Lib\site-packages\pandas\core\groupby\generic.py:1947, in DataFrameGroupBy.__getitem__(self, key)
#    1943 # per GH 23566
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
# -> 1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
#    1951 return super().__getitem__(key)
#
# ValueError: Cannot subset columns with a tuple with more than one element. Use a list instead.

# %%
data.groupby('Product').agg(
    Avg_Quantity=('Quantity', 'mean'),
    Avg_Revenue=('Revenue', 'mean')
)
# Out:
#                     Avg_Quantity  Avg_Revenue
# Product
# Beverages             699.760000  2064.292000
# Burgers               558.038462  7248.919615
# Chicken Sandwiches    214.096154  2204.085577
# Fries                 627.901961  2463.266078
# Sides & Other         200.000000   998.000000
